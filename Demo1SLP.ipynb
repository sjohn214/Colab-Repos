# %% [markdown]
# <a href="https://colab.research.google.com/github/sjohn214/Colab-Repos/blob/main/Demo1SLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## This is my first ***notebook***

# %%
print("ShannBann7")
# Out:
# ShannBann7
